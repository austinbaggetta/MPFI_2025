# %%
import os
import numpy as np
import xarray as xr
import plotly.graph_objects as go

from utilities import custom_graph_template

# %%
## Settings
rpath = '../intermediate/minian_output'
fig_path = '../figs'
data_type = 'YrA'

# %% [markdown]
# ### Load data for one mouse and one session to plot activity across time.

# %%
## Load data
mouse = 'maddie'
date = '2025_04_16' 
timestamp = '16_04_56' 

data = xr.open_dataset(os.path.join(rpath, f'{mouse}/{date}/{timestamp}/{data_type}.nc'))[data_type]
data
# Out:
# <xarray.DataArray 'YrA' (unit_id: 526, frame: 8993)> Size: 38MB
# [4730318 values with dtype=float64]
# Coordinates:
#     session         <U10 40B ...
#     animal          <U6 24B ...
#     timestamp       <U8 32B ...
#   * unit_id         (unit_id) int64 4kB 1 2 3 4 5 6 ... 559 560 561 562 563 564
#     session_id      (frame) <U1 36kB ...
#     recording_type  (frame) <U7 252kB ...
#     timestamps      (frame) float64 72kB ...
#   * frame           (frame) int64 72kB 0 1 2 3 4 5 ... 8988 8989 8990 8991 8992
#     unix            (frame) float64 72kB ...
